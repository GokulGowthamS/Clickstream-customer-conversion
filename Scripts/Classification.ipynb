# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import xgboost as xgb
from xgboost import XGBRegressor

from imblearn.over_sampling import SMOTE

import pickle

import os

import warnings
warnings.filterwarnings('ignore')

# %%
file_path = 'F:\\Guvi Projects\\Clickstream - Customer Conversion\\Preprocessed_Data\\processed_data.csv'

# %%
data = pd.read_csv(file_path)
data.head()
# Out:
#    month  day  country  page1_main_category  colour  location  \
# 0      6   22       29                    3      13         1
# 1      5   19       29                    2      13         3
# 2      7   15       29                    3       9         5
# 3      5    2       29                    2       2         4
# 4      6    9       29                    2       9         5
#
#    model_photography  page  avg_price  unique_products  browsing_depth  \
# 0                  2     2  46.928571               55               4
# 1                  1     2  57.666667                4               2
# 2                  1     1  38.900000                9               3
# 3                  1     1  51.666667                5               2
# 4                  1     2  52.333333               12               2
#
#    weekend  high_price_preference
# 0        1                      1
# 1        0                      1
# 2        0                      1
# 3        0                      0
# 4        0                      1

# %%
val = data.drop('high_price_preference', axis = 1)
tar = data['high_price_preference']

# %%
fs = XGBRegressor(n_estimators = 200, random_state = 90)

# %%
fs.fit(val, tar)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None,
#              num_parallel_tree=None, random_state=90, ...)

# %%
selected = pd.DataFrame({
    "col": val.columns,
    'sco':fs.feature_importances_
}).sort_values('sco', ascending = False).head(9)['col'].to_list()

# %%
val = val[selected]

tar = tar

# %%
tar.value_counts()
# Out:
# high_price_preference
# 0    80230
# 1    52149
# Name: count, dtype: int64

# %%
smote = SMOTE()

# %%
os_val, os_tar = smote.fit_resample(val, tar)

# %%
os_tar.value_counts()
# Out:
# high_price_preference
# 1    80230
# 0    80230
# Name: count, dtype: int64

# %%
x_train, x_test, tr_lab, ts_lab = train_test_split(os_val, os_tar, test_size = 0.2, random_state = 65)

# %% [markdown]
# #### Logistic Regression

# %%
def build_logistic_regression(x_train, x_test, tr_lab, ts_lab):

    print("\n----------Building Logistic Regression----------")

    param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga'],
    'max_iter': [500, 1000]
    }

    lr_model = LogisticRegression(random_state=65)

    random_search = RandomizedSearchCV(
        lr_model,
        param_grid,
        n_iter=20,
        cv=3,
        scoring='accuracy',
        n_jobs=-1,
        verbose=1
    )

    random_search.fit(x_train, tr_lab)

    best_model = random_search.best_estimator_

    ts_pred = best_model.predict(x_test)

    ts_probs = best_model.predict_proba(x_test)[:, 1]

    fpr, tpr, _ = roc_curve(ts_lab, ts_probs)

    auc_score = roc_auc_score(ts_lab, ts_probs)

    accuracy = accuracy_score(ts_lab, ts_pred)

    print(f"Best Parameters: {random_search.best_params_}")
    print(f"Best Cross-Validation Score: {random_search.best_score_:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(ts_lab, ts_pred))

    plt.figure(figsize=(5, 4))
    cm = confusion_matrix(ts_lab, ts_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')
    plt.title('Logistic Regression Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"ROC AUC = {auc_score:.2f}", color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='red')
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC Curve")
    plt.legend()
    plt.show()
            
    return best_model

# %% [markdown]
# #### Decision Tree

# %%
def build_decision_tree(x_train, x_test, tr_lab, ts_lab):

    print("\n----------Building Decision Tree----------")

    param_grid = {
        'max_depth': [None, 5, 10, 15, 20, 30],  
        'min_samples_split': [2, 5, 10, 15],  
        'min_samples_leaf': [1, 2, 4, 6],  
        'criterion': ['gini', 'entropy'],  
        'splitter': ['best', 'random']
    }

    dt_model = DecisionTreeClassifier(random_state=65)

    random_search = RandomizedSearchCV(
        dt_model,
        param_grid,
        n_iter=20,
        cv=3,
        scoring='accuracy',
        n_jobs=-1,
        verbose=1
    )

    random_search.fit(x_train, tr_lab)

    best_model = random_search.best_estimator_

    ts_pred = best_model.predict(x_test)

    ts_probs = best_model.predict_proba(x_test)[:, 1]

    fpr, tpr, _ = roc_curve(ts_lab, ts_probs)

    auc_score = roc_auc_score(ts_lab, ts_probs)
    
    accuracy = accuracy_score(ts_lab, ts_pred)

    print(f"Best Parameters: {random_search.best_params_}")
    print(f"Best Cross-Validation Score: {random_search.best_score_:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(ts_lab, ts_pred))

    plt.figure(figsize=(5, 4))
    cm = confusion_matrix(ts_lab, ts_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Decision Tree Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"ROC AUC = {auc_score:.2f}", color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='red')
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC Curve")
    plt.legend()
    plt.show()

    return best_model

# %% [markdown]
# #### Random Forest

# %%
def build_random_forest(x_train, x_test, tr_lab, ts_lab):

    print('\n----------Building Random Forest----------')

    param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['sqrt', 'log2'], 
        'bootstrap': [True, False]
    }

    rf_model = RandomForestClassifier(random_state=65, warm_start=True, n_jobs=-1)

    random_search = RandomizedSearchCV(
        rf_model,
        param_grid,
        n_iter=20,
        cv=3,
        scoring='accuracy',
        n_jobs=-1,
        verbose=1
    )

    random_search.fit(x_train, tr_lab)

    best_model = random_search.best_estimator_

    ts_pred = best_model.predict(x_test)

    ts_probs = best_model.predict_proba(x_test)[:, 1]

    fpr, tpr, _ = roc_curve(ts_lab, ts_probs)

    auc_score = roc_auc_score(ts_lab, ts_probs)
    
    accuracy = accuracy_score(ts_lab, ts_pred)

    print(f"Best Parameters: {random_search.best_params_}")
    print(f"Best Cross-Validation Score: {random_search.best_score_:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(ts_lab, ts_pred))

    plt.figure(figsize=(5, 4))
    cm = confusion_matrix(ts_lab, ts_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')
    plt.title('Random Forest Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"ROC AUC = {auc_score:.2f}", color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='red')
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC Curve")
    plt.legend()
    plt.show()

    return best_model

# %% [markdown]
# #### XG Boost

# %%
def build_xgboost(x_train, x_test, tr_lab, ts_lab):

    print('\n----------Building XGBoost----------')

    param_grid = {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.1, 0.2],
        'max_depth': [3, 5, 7],
        'subsample': [0.7, 0.8, 1.0],
        'colsample_bytree': [0.7, 0.8, 1.0],  
        'gamma': [0, 0.1, 0.2], 
        'reg_lambda': [1, 2, 5]
    }

    xgb_model = xgb.XGBClassifier(random_state=65, tree_method="hist", gpu_id=0)

    random_search = RandomizedSearchCV (
        xgb_model,
        param_grid,
        n_iter = 20,  
        cv=3,  
        scoring='accuracy',
        n_jobs=-1,
        verbose=1,
    )
    

    random_search.fit(x_train, tr_lab, eval_set=[(x_test, ts_lab)])

    best_model = random_search.best_estimator_

    ts_pred = best_model.predict(x_test)

    ts_probs = best_model.predict_proba(x_test)[:, 1]

    fpr, tpr, _ = roc_curve(ts_lab, ts_probs)

    auc_score = roc_auc_score(ts_lab, ts_probs)

    accuracy = accuracy_score(ts_lab, ts_pred)

    print(f"Best Parameters: {random_search.best_params_}")
    print(f"Best Cross-Validation Score: {random_search.best_score_:.4f}")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(ts_lab, ts_pred))

    plt.figure(figsize=(5, 4))
    cm = confusion_matrix(ts_lab, ts_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('XGBoost Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"ROC AUC = {auc_score:.2f}", color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='red')
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC Curve")
    plt.legend()
    plt.show()

    return best_model

# %% [markdown]
# #### Neural Networks

# %%
def build_neural_network(x_train, x_test, tr_lab, ts_lab):

    print("\n----------Building Neural Network----------")

    nn_model = Sequential([
        Dense(100, activation='relu', input_shape = (x_train.shape[1],)),
        Dropout(0.2), 
        Dense(75, activation= 'relu'),
        Dropout(0.2),
        Dense(50, activation='relu'), 
        Dropout(0.2),
        Dense(25, activation='relu'), 
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])

    nn_model.compile(optimizer = Adam(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    history = nn_model.fit(x_train, tr_lab,
                        validation_split=0.2,  
                        epochs=50, 
                        batch_size=32,  
                        callbacks=[early_stopping],
                        verbose=1)
    
    ts_pred = (nn_model.predict(x_test) > 0.5).astype(int)

    ts_probs = nn_model.predict(x_test).flatten()

    fpr, tpr, _ = roc_curve(ts_lab, ts_probs)

    auc_score = roc_auc_score(ts_lab, ts_probs)

    accuracy = accuracy_score(ts_lab, ts_pred)

    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(ts_lab, ts_pred))

    plt.figure(figsize=(5, 4))
    cm = confusion_matrix(ts_lab, ts_pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis')
    plt.title('Neural Network Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"ROC AUC = {auc_score:.2f}", color='blue')
    plt.plot([0, 1], [0, 1], linestyle='--', color='red')
    plt.xlabel("False Positive Rate (FPR)")
    plt.ylabel("True Positive Rate (TPR)")
    plt.title("ROC Curve")
    plt.legend()
    plt.show()

    return nn_model, history

# %% [markdown]
# #### Comparing Models

# %%
def compare_models(models_dict, x_test, ts_lab):

    print("\n----------Comparing Models----------")

    results = {}

    for name, model in models_dict.items():
        if hasattr(model, "predict"):
            ts_probs = model.predict(x_test)
            ts_pred = (ts_probs > 0.5).astype(int)
        else:
            ts_pred = model.predict(x_test)

        accuracy = accuracy_score(ts_lab, ts_pred)
        auc_score = roc_auc_score(ts_lab, ts_pred)
        results[name] = {
            'Accuracy': accuracy,
            'Roc-Auc Score': auc_score,
            'Predictions': ts_pred
            
        }
    
    comparison = pd.DataFrame(results).T[['Accuracy', 'Roc-Auc Score']]

    comparison = comparison.sort_values('Accuracy', ascending = False)

    print(comparison)

    best_model_name = comparison.index[0]

    best_model = models_dict[best_model_name]

    plt.figure(figsize=(5, 4))
    sns.barplot(x=comparison.index, y='Accuracy', data=comparison)
    plt.title('Model Accuracy Comparison')
    plt.xlabel('Model')
    plt.ylabel('Accuracy')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    return comparison, results, best_model, best_model_name

# %% [markdown]
# #### Final Call

# %%
def run_all_models(x_train, x_test, tr_lab, ts_lab):

    lr_model = build_logistic_regression(x_train, x_test, tr_lab, ts_lab)
    dt_model = build_decision_tree(x_train, x_test, tr_lab, ts_lab)
    rf_model = build_random_forest(x_train, x_test, tr_lab, ts_lab)
    xgb_model = build_xgboost(x_train, x_test, tr_lab, ts_lab)
    nn_model, _ = build_neural_network(x_train, x_test, tr_lab, ts_lab)

    models = {
        'Logistic Regression': lr_model,
        'Decision Tree': dt_model,
        'Random Forest': rf_model,
        'XG Boost': xgb_model,
        'Neural Network': nn_model
    }

    comparison, results, best_model, best_model_name = compare_models(models, x_test, ts_lab)

    pickle_path = 'F:\\Guvi Projects\\Clickstream - Customer Conversion\\Pickles'

    os.makedirs(pickle_path, exist_ok=True)
    
    best_model_class = os.path.join(pickle_path, 'best_model_class.pkl')

    with open(best_model_class, 'wb') as file:
        pickle.dump(best_model, file)

    print(f"\nBest Model for Classification: {best_model_name} saved to 'best_model_class.pkl'")

    return models, comparison, results, best_model, best_model_name

# %%
models, comparison, results, best_model, best_model_name = run_all_models(x_train, x_test, tr_lab, ts_lab)
# Out:
# ----------Building Logistic Regression----------
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Parameters: {'solver': 'saga', 'penalty': 'l1', 'max_iter': 1000, 'C': 0.1}
# Best Cross-Validation Score: 0.6866
# Test Accuracy: 0.6881
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.68      0.69     16048
#            1       0.69      0.70      0.69     16044
#
#     accuracy                           0.69     32092
#    macro avg       0.69      0.69      0.69     32092
# weighted avg       0.69      0.69      0.69     32092
# ----------Building Decision Tree----------
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Parameters: {'splitter': 'random', 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_depth': 20, 'criterion': 'gini'}
# Best Cross-Validation Score: 0.9374
# Test Accuracy: 0.9355
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94     16048
#            1       0.93      0.94      0.94     16044
#
#     accuracy                           0.94     32092
#    macro avg       0.94      0.94      0.94     32092
# weighted avg       0.94      0.94      0.94     32092
# ----------Building Random Forest----------
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Best Parameters: {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 20, 'bootstrap': False}
# Best Cross-Validation Score: 0.9412
# Test Accuracy: 0.9421
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94     16048
#            1       0.92      0.96      0.94     16044
#
#     accuracy                           0.94     32092
#    macro avg       0.94      0.94      0.94     32092
# weighted avg       0.94      0.94      0.94     32092
# ----------Building XGBoost----------
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [0]	validation_0-logloss:0.62521
# [1]	validation_0-logloss:0.57809
# [2]	validation_0-logloss:0.54581
# [3]	validation_0-logloss:0.52020
# [4]	validation_0-logloss:0.50125
# [5]	validation_0-logloss:0.48367
# [6]	validation_0-logloss:0.46133
# [7]	validation_0-logloss:0.44834
# [8]	validation_0-logloss:0.43826
# [9]	validation_0-logloss:0.43231
# [10]	validation_0-logloss:0.41764
# [11]	validation_0-logloss:0.41101
# [12]	validation_0-logloss:0.40610
# [13]	validation_0-logloss:0.40015
# [14]	validation_0-logloss:0.38546
# [15]	validation_0-logloss:0.37944
# [16]	validation_0-logloss:0.37611
# [17]	validation_0-logloss:0.37084
# [18]	validation_0-logloss:0.36311
# [19]	validation_0-logloss:0.35571
# [20]	validation_0-logloss:0.35450
# [21]	validation_0-logloss:0.35080
# [22]	validation_0-logloss:0.33625
# [23]	validation_0-logloss:0.33265
# [24]	validation_0-logloss:0.32352
# [25]	validation_0-logloss:0.31517
# [26]	validation_0-logloss:0.31120
# [27]	validation_0-logloss:0.30281
# [28]	validation_0-logloss:0.29776
# [29]	validation_0-logloss:0.29630
# [30]	validation_0-logloss:0.29291
# [31]	validation_0-logloss:0.29058
# [32]	validation_0-logloss:0.28182
# [33]	validation_0-logloss:0.27808
# [34]	validation_0-logloss:0.27659
# [35]	validation_0-logloss:0.26860
# [36]	validation_0-logloss:0.26737
# [37]	validation_0-logloss:0.25957
# [38]	validation_0-logloss:0.25012
# [39]	validation_0-logloss:0.24671
# [40]	validation_0-logloss:0.24587
# [41]	validation_0-logloss:0.24433
# [42]	validation_0-logloss:0.24361
# [43]	validation_0-logloss:0.24320
# [44]	validation_0-logloss:0.24115
# [45]	validation_0-logloss:0.22862
# [46]	validation_0-logloss:0.22468
# [47]	validation_0-logloss:0.22399
# [48]	validation_0-logloss:0.22265
# [49]	validation_0-logloss:0.21799
# [50]	validation_0-logloss:0.21441
# [51]	validation_0-logloss:0.20767
# [52]	validation_0-logloss:0.20557
# [53]	validation_0-logloss:0.20305
# [54]	validation_0-logloss:0.19867
# [55]	validation_0-logloss:0.19433
# [56]	validation_0-logloss:0.19145
# [57]	validation_0-logloss:0.18978
# [58]	validation_0-logloss:0.18739
# [59]	validation_0-logloss:0.18631
# [60]	validation_0-logloss:0.18577
# [61]	validation_0-logloss:0.18514
# [62]	validation_0-logloss:0.18465
# [63]	validation_0-logloss:0.18429
# [64]	validation_0-logloss:0.18328
# [65]	validation_0-logloss:0.17650
# [66]	validation_0-logloss:0.17533
# [67]	validation_0-logloss:0.17132
# [68]	validation_0-logloss:0.16830
# [69]	validation_0-logloss:0.16758
# [70]	validation_0-logloss:0.16527
# [71]	validation_0-logloss:0.16340
# [72]	validation_0-logloss:0.16312
# [73]	validation_0-logloss:0.16279
# [74]	validation_0-logloss:0.16257
# [75]	validation_0-logloss:0.16214
# [76]	validation_0-logloss:0.16164
# [77]	validation_0-logloss:0.16154
# [78]	validation_0-logloss:0.16111
# [79]	validation_0-logloss:0.15805
# [80]	validation_0-logloss:0.15652
# [81]	validation_0-logloss:0.15509
# [82]	validation_0-logloss:0.15416
# [83]	validation_0-logloss:0.15162
# [84]	validation_0-logloss:0.15036
# [85]	validation_0-logloss:0.14902
# [86]	validation_0-logloss:0.14847
# [87]	validation_0-logloss:0.14822
# [88]	validation_0-logloss:0.14803
# [89]	validation_0-logloss:0.14759
# [90]	validation_0-logloss:0.14674
# [91]	validation_0-logloss:0.14662
# [92]	validation_0-logloss:0.14643
# [93]	validation_0-logloss:0.14496
# [94]	validation_0-logloss:0.14407
# [95]	validation_0-logloss:0.14364
# [96]	validation_0-logloss:0.14276
# [97]	validation_0-logloss:0.14240
# [98]	validation_0-logloss:0.14232
# [99]	validation_0-logloss:0.14228
# [100]	validation_0-logloss:0.14200
# [101]	validation_0-logloss:0.14110
# [102]	validation_0-logloss:0.14044
# [103]	validation_0-logloss:0.14012
# [104]	validation_0-logloss:0.13999
# [105]	validation_0-logloss:0.13994
# [106]	validation_0-logloss:0.13954
# [107]	validation_0-logloss:0.13950
# [108]	validation_0-logloss:0.13941
# [109]	validation_0-logloss:0.13922
# [110]	validation_0-logloss:0.13914
# [111]	validation_0-logloss:0.13852
# [112]	validation_0-logloss:0.13775
# [113]	validation_0-logloss:0.13738
# [114]	validation_0-logloss:0.13695
# [115]	validation_0-logloss:0.13692
# [116]	validation_0-logloss:0.13678
# [117]	validation_0-logloss:0.13674
# [118]	validation_0-logloss:0.13659
# [119]	validation_0-logloss:0.13650
# [120]	validation_0-logloss:0.13574
# [121]	validation_0-logloss:0.13560
# [122]	validation_0-logloss:0.13555
# [123]	validation_0-logloss:0.13546
# [124]	validation_0-logloss:0.13515
# [125]	validation_0-logloss:0.13502
# [126]	validation_0-logloss:0.13409
# [127]	validation_0-logloss:0.13353
# [128]	validation_0-logloss:0.13302
# [129]	validation_0-logloss:0.13240
# [130]	validation_0-logloss:0.13190
# [131]	validation_0-logloss:0.13132
# [132]	validation_0-logloss:0.13074
# [133]	validation_0-logloss:0.13004
# [134]	validation_0-logloss:0.12905
# [135]	validation_0-logloss:0.12896
# [136]	validation_0-logloss:0.12859
# [137]	validation_0-logloss:0.12839
# [138]	validation_0-logloss:0.12835
# [139]	validation_0-logloss:0.12813
# [140]	validation_0-logloss:0.12739
# [141]	validation_0-logloss:0.12735
# [142]	validation_0-logloss:0.12721
# [143]	validation_0-logloss:0.12699
# [144]	validation_0-logloss:0.12679
# [145]	validation_0-logloss:0.12672
# [146]	validation_0-logloss:0.12668
# [147]	validation_0-logloss:0.12668
# [148]	validation_0-logloss:0.12621
# [149]	validation_0-logloss:0.12608
# [150]	validation_0-logloss:0.12606
# [151]	validation_0-logloss:0.12585
# [152]	validation_0-logloss:0.12538
# [153]	validation_0-logloss:0.12536
# [154]	validation_0-logloss:0.12523
# [155]	validation_0-logloss:0.12471
# [156]	validation_0-logloss:0.12465
# [157]	validation_0-logloss:0.12465
# [158]	validation_0-logloss:0.12434
# [159]	validation_0-logloss:0.12421
# [160]	validation_0-logloss:0.12396
# [161]	validation_0-logloss:0.12392
# [162]	validation_0-logloss:0.12392
# [163]	validation_0-logloss:0.12384
# [164]	validation_0-logloss:0.12384
# [165]	validation_0-logloss:0.12379
# [166]	validation_0-logloss:0.12378
# [167]	validation_0-logloss:0.12351
# [168]	validation_0-logloss:0.12347
# [169]	validation_0-logloss:0.12319
# [170]	validation_0-logloss:0.12322
# [171]	validation_0-logloss:0.12321
# [172]	validation_0-logloss:0.12319
# [173]	validation_0-logloss:0.12317
# [174]	validation_0-logloss:0.12317
# [175]	validation_0-logloss:0.12318
# [176]	validation_0-logloss:0.12315
# [177]	validation_0-logloss:0.12314
# [178]	validation_0-logloss:0.12312
# [179]	validation_0-logloss:0.12307
# [180]	validation_0-logloss:0.12299
# [181]	validation_0-logloss:0.12296
# [182]	validation_0-logloss:0.12300
# [183]	validation_0-logloss:0.12300
# [184]	validation_0-logloss:0.12299
# [185]	validation_0-logloss:0.12295
# [186]	validation_0-logloss:0.12272
# [187]	validation_0-logloss:0.12255
# [188]	validation_0-logloss:0.12247
# [189]	validation_0-logloss:0.12243
# [190]	validation_0-logloss:0.12193
# [191]	validation_0-logloss:0.12161
# [192]	validation_0-logloss:0.12147
# [193]	validation_0-logloss:0.12146
# [194]	validation_0-logloss:0.12132
# [195]	validation_0-logloss:0.12127
# [196]	validation_0-logloss:0.12091
# [197]	validation_0-logloss:0.12075
# [198]	validation_0-logloss:0.12065
# [199]	validation_0-logloss:0.12059
# [200]	validation_0-logloss:0.12050
# [201]	validation_0-logloss:0.12048
# [202]	validation_0-logloss:0.12013
# [203]	validation_0-logloss:0.11982
# [204]	validation_0-logloss:0.11974
# [205]	validation_0-logloss:0.11976
# [206]	validation_0-logloss:0.11973
# [207]	validation_0-logloss:0.11973
# [208]	validation_0-logloss:0.11970
# [209]	validation_0-logloss:0.11961
# [210]	validation_0-logloss:0.11962
# [211]	validation_0-logloss:0.11958
# [212]	validation_0-logloss:0.11945
# [213]	validation_0-logloss:0.11944
# [214]	validation_0-logloss:0.11939
# [215]	validation_0-logloss:0.11936
# [216]	validation_0-logloss:0.11934
# [217]	validation_0-logloss:0.11933
# [218]	validation_0-logloss:0.11933
# [219]	validation_0-logloss:0.11927
# [220]	validation_0-logloss:0.11915
# [221]	validation_0-logloss:0.11914
# [222]	validation_0-logloss:0.11914
# [223]	validation_0-logloss:0.11914
# [224]	validation_0-logloss:0.11912
# [225]	validation_0-logloss:0.11899
# [226]	validation_0-logloss:0.11899
# [227]	validation_0-logloss:0.11899
# [228]	validation_0-logloss:0.11899
# [229]	validation_0-logloss:0.11890
# [230]	validation_0-logloss:0.11888
# [231]	validation_0-logloss:0.11888
# [232]	validation_0-logloss:0.11888
# [233]	validation_0-logloss:0.11888
# [234]	validation_0-logloss:0.11889
# [235]	validation_0-logloss:0.11891
# [236]	validation_0-logloss:0.11867
# [237]	validation_0-logloss:0.11867
# [238]	validation_0-logloss:0.11858
# [239]	validation_0-logloss:0.11858
# [240]	validation_0-logloss:0.11858
# [241]	validation_0-logloss:0.11859
# [242]	validation_0-logloss:0.11855
# [243]	validation_0-logloss:0.11851
# [244]	validation_0-logloss:0.11850
# [245]	validation_0-logloss:0.11852
# [246]	validation_0-logloss:0.11848
# [247]	validation_0-logloss:0.11837
# [248]	validation_0-logloss:0.11833
# [249]	validation_0-logloss:0.11833
# [250]	validation_0-logloss:0.11830
# [251]	validation_0-logloss:0.11829
# [252]	validation_0-logloss:0.11827
# [253]	validation_0-logloss:0.11825
# [254]	validation_0-logloss:0.11806
# [255]	validation_0-logloss:0.11806
# [256]	validation_0-logloss:0.11792
# [257]	validation_0-logloss:0.11788
# [258]	validation_0-logloss:0.11788
# [259]	validation_0-logloss:0.11784
# [260]	validation_0-logloss:0.11785
# [261]	validation_0-logloss:0.11785
# [262]	validation_0-logloss:0.11785
# [263]	validation_0-logloss:0.11785
# [264]	validation_0-logloss:0.11786
# [265]	validation_0-logloss:0.11785
# [266]	validation_0-logloss:0.11785
# [267]	validation_0-logloss:0.11787
# [268]	validation_0-logloss:0.11785
# [269]	validation_0-logloss:0.11785
# [270]	validation_0-logloss:0.11785
# [271]	validation_0-logloss:0.11783
# [272]	validation_0-logloss:0.11783
# [273]	validation_0-logloss:0.11782
# [274]	validation_0-logloss:0.11779
# [275]	validation_0-logloss:0.11773
# [276]	validation_0-logloss:0.11772
# [277]	validation_0-logloss:0.11770
# [278]	validation_0-logloss:0.11767
# [279]	validation_0-logloss:0.11766
# [280]	validation_0-logloss:0.11762
# [281]	validation_0-logloss:0.11759
# [282]	validation_0-logloss:0.11752
# [283]	validation_0-logloss:0.11755
# [284]	validation_0-logloss:0.11754
# [285]	validation_0-logloss:0.11753
# [286]	validation_0-logloss:0.11754
# [287]	validation_0-logloss:0.11755
# [288]	validation_0-logloss:0.11755
# [289]	validation_0-logloss:0.11757
# [290]	validation_0-logloss:0.11756
# [291]	validation_0-logloss:0.11753
# [292]	validation_0-logloss:0.11753
# [293]	validation_0-logloss:0.11745
# [294]	validation_0-logloss:0.11744
# [295]	validation_0-logloss:0.11745
# [296]	validation_0-logloss:0.11743
# [297]	validation_0-logloss:0.11744
# [298]	validation_0-logloss:0.11739
# [299]	validation_0-logloss:0.11737
# Best Parameters: {'subsample': 1.0, 'reg_lambda': 5, 'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.2, 'gamma': 0.1, 'colsample_bytree': 1.0}
# Best Cross-Validation Score: 0.9423
# Test Accuracy: 0.9419
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94     16048
#            1       0.92      0.96      0.94     16044
#
#     accuracy                           0.94     32092
#    macro avg       0.94      0.94      0.94     32092
# weighted avg       0.94      0.94      0.94     32092
# ----------Building Neural Network----------
# Epoch 1/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 7s 1ms/step - accuracy: 0.5998 - loss: 0.6864 - val_accuracy: 0.6827 - val_loss: 0.5851
# Epoch 2/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.6837 - loss: 0.5805 - val_accuracy: 0.7251 - val_loss: 0.5269
# Epoch 3/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.7256 - loss: 0.5332 - val_accuracy: 0.7633 - val_loss: 0.4768
# Epoch 4/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.7524 - loss: 0.4926 - val_accuracy: 0.7992 - val_loss: 0.4170
# Epoch 5/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.7761 - loss: 0.4557 - val_accuracy: 0.8212 - val_loss: 0.3709
# Epoch 6/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.7876 - loss: 0.4344 - val_accuracy: 0.8365 - val_loss: 0.3441
# Epoch 7/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8014 - loss: 0.4085 - val_accuracy: 0.8435 - val_loss: 0.3225
# Epoch 8/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8104 - loss: 0.3893 - val_accuracy: 0.8632 - val_loss: 0.2947
# Epoch 9/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8205 - loss: 0.3703 - val_accuracy: 0.8641 - val_loss: 0.2863
# Epoch 10/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8285 - loss: 0.3544 - val_accuracy: 0.8738 - val_loss: 0.2610
# Epoch 11/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8337 - loss: 0.3429 - val_accuracy: 0.8731 - val_loss: 0.2705
# Epoch 12/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8367 - loss: 0.3413 - val_accuracy: 0.8874 - val_loss: 0.2544
# Epoch 13/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8404 - loss: 0.3324 - val_accuracy: 0.8900 - val_loss: 0.2218
# Epoch 14/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8495 - loss: 0.3199 - val_accuracy: 0.8984 - val_loss: 0.2218
# Epoch 15/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8495 - loss: 0.3197 - val_accuracy: 0.8995 - val_loss: 0.2110
# Epoch 16/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8514 - loss: 0.3105 - val_accuracy: 0.8961 - val_loss: 0.2219
# Epoch 17/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8554 - loss: 0.3084 - val_accuracy: 0.8945 - val_loss: 0.2215
# Epoch 18/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8557 - loss: 0.3045 - val_accuracy: 0.8994 - val_loss: 0.2024
# Epoch 19/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8608 - loss: 0.2964 - val_accuracy: 0.8861 - val_loss: 0.2361
# Epoch 20/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8587 - loss: 0.2946 - val_accuracy: 0.8997 - val_loss: 0.2084
# Epoch 21/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.8602 - loss: 0.2934 - val_accuracy: 0.8974 - val_loss: 0.2102
# Epoch 22/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.8623 - loss: 0.2896 - val_accuracy: 0.9011 - val_loss: 0.2070
# Epoch 23/50
# 3210/3210 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.8646 - loss: 0.2908 - val_accuracy: 0.8980 - val_loss: 0.2064
# 1003/1003 ━━━━━━━━━━━━━━━━━━━━ 1s 597us/step
# 1003/1003 ━━━━━━━━━━━━━━━━━━━━ 1s 560us/step
# Test Accuracy: 0.8974
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89     16048
#            1       0.86      0.94      0.90     16044
#
#     accuracy                           0.90     32092
#    macro avg       0.90      0.90      0.90     32092
# weighted avg       0.90      0.90      0.90     32092
# ----------Comparing Models----------
# 1003/1003 ━━━━━━━━━━━━━━━━━━━━ 1s 560us/step
#                      Accuracy Roc-Auc Score
# Random Forest        0.942104      0.942107
# XG Boost             0.941855      0.941857
# Decision Tree        0.935529       0.93553
# Neural Network       0.897358      0.897363
# Logistic Regression  0.688053      0.688054
# Best Model for Classification: Random Forest saved to 'best_model_class.pkl'
